# %%
import pandas as py

# %%
dataframe = py.read_csv('US_births_2000-2014_SSA.csv')

# %%
year = dataframe[dataframe.year == 'Year']

# %%
month = dataframe[dataframe.month == 'Month']

# %%
births = dataframe[dataframe.births == 'Births']

# %%
dayofweek = dataframe[dataframe.day_of_week == 'Day of Week']

# %%
dataframe.plot( x = "day_of_week", y = "births", kind = "line")

# %%
dataframe.plot( x = "date_of_month", y = "births", kind = "line")

# %%
import matplotlib.pyplot as plt

# %%
dataframe.plot( x = "date_of_month", y = "births", kind = "line")

# %%
width = 0.40

# %%
fig, dataframe = plt.subplots()

# %%
dataframe.bar('year', 'births', width)
# Out:
# <BarContainer object of 1 artists>

# %%
dataframe.set_ylabel('Births')
# Out:
# Text(3.200000000000003, 0.5, 'Births')

# %%
dataframe.set_title("US Births")
# Out:
# Text(0.5, 1.0, 'US Births')

# %%
dataframe.legend()
# Out:
# No handles with labels found to put in legend.

# %%
plt.show()

# %%
year = ['2000', '2001', '2002', '2003', '2004', '2005', '2006',
       '2007', '2008', '2009', '2010', '2011']

#Does not match with the data from the csv file. Just a placeholde 
births = [216000, 230000, 215000, 207000, 217000, 223000, 231000, 
          224000, 233000, 244000, 255000, 255000]

width = 0.35       # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots()

ax.bar(year, births, width, label='Births')


ax.set_ylabel('Births')
ax.set_title('US Births')
ax.legend()

plt.show()
